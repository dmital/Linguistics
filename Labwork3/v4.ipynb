# %% [markdown]
# # Лабораторная работа 3

# %% [markdown]
# *  ### В этой работе нужно установить влияние синтаксиса на индивидуальный авторский стиль.
# *  ### Выбранные произведения анализируются посредством синтаксического анализатора
# *  ### После этого следует получить кумулятивные статистики по всему тексту...
# *  ### ... и использовать их в качестве атрибутов при решении задачи кластеризации.

# %% [markdown]
# #### Выводим список авторов, произведения которых используются в работе:

# %%
import os

texts = {}

for writer in sorted(os.listdir('./books')):
    textNames = sorted(os.listdir('./books/' + writer))
    texts.update({writer: textNames})

writers = list(texts.keys())

print(writers)
# Out:
# ['Аркадий Гайдар', 'Жюль Верн', 'Лев Толстой', 'Фазиль Искандер', 'Федор Достоевский']

# %% [markdown]
# #### Теперь выводим список самих произведений:

# %%
print(texts)
# Out:
# {'Аркадий Гайдар': ['Судьба барабанщика.txt', 'Тимур и его команда.txt', 'Школа.txt'], 'Жюль Верн': ['Двадцать тысяч лье под водой.txt', 'Путешествие к центру Земли.txt', 'Таинственный остров.txt'], 'Лев Толстой': ['Анна Каренина.txt', 'Крейцерова соната.txt', 'Хаджи-Мурат.txt'], 'Фазиль Искандер': ['Морской скорпион.txt', 'Поэт.txt', 'Стоянка человека.txt'], 'Федор Достоевский': ['Белые ночи.txt', 'Игрок.txt', 'Преступление и наказание.txt']}

# %% [markdown]
# #### Разбиваем входные тексты на части по n символов:

# %%
import itertools
def grouper(n, iterable):
    args = [iter(iterable)] * n
    return list("".join([e for e in t if e != None]) for t in itertools.zip_longest(*args))

# %% [markdown]
# #### Загружаем тексты:

# %%
data = []
label_list = []
for writer in writers:
    books = []
    for text in texts[writer]:
        with open('./books/' + writer + '/' + text) as bookFile:
            book = bookFile.read().replace('\n', ' ').replace('\xa0', ' ')
            for b in grouper(100000, book):
                books.append(b)
                label_list.append(writer + '_' + text[:-4])
    data.append(books)

# %% [markdown]
# #### Загружаем дополнительные модули для работы с текстом

# %%
import spacy
nlp = spacy.load('/home/ocaml/spacy-ru-master/ru2/')

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/ocaml/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %% [markdown]
# #### Выводим большой отрывок первой книги:

# %%
data[0][0]
# Out:
# ' \x14Аркадий Гайдар. Судьба барабанщика\x15     ---------------------------------------------------------------------  Книга: А.Гайдар. Собрание сочинений в трех томах. Том 2  Издательство "Правда", Москва, 1986  OCR & SpellCheck: Zmiy (zpdd@chat.ru), 13 декабря 2001  ---------------------------------------------------------------------    Когда-то мой отец воевал с белыми, был ранен, бежал из плена, потом по должности командира саперной роты ушел в запас. Мать моя утонула, купаясь на реке Волге, когда мне было восемь лет. От большого горя мы переехали в Москву. И здесь через два года отец женился на красивой девушке Валентине Долгунцовой. Люди говорят, что сначала жили мы скромно и тихо. Небогатую квартиру нашу держала Валентина в чистоте. Одевалась просто. Об отце заботилась и меня не обижала.  Но тут окончились распределители, разные талоны, хлебные карточки. Стал народ жить получше, побогаче. Стала чаще и чаще ходить Валентина в кино, то одна, то с провожатыми. Домой возвращалась тогда рассеянная, задумчивая и, что там в кино видела, никогда ни отцу, ни мне не рассказывала.  И как-то вскоре - совсем для нас неожиданно - отца моего назначили директором большого текстильного магазина.  Был на радостях пир. Пришли гости. Пришел старый отцовский товарищ Платон Половцев, а с ним и его дочка Нина, с которой, как только увиделись мы, - рассмеялись, обнялись, и больше нам за весь вечер ни до кого не было дела.  Стали теперь кое-когда присылать за отцом машину. Чаще и чаще стал он ходить на разные заседания и совещания. Брал с собой раза два он и Валентину на какие-то банкеты. И стала вдруг Валентина злой, раздражительной. Начальников отцовских хвалила, жен их ругала, а крепкого и высокого отца моего называла рохлей и тряпкой.  Много у отца в магазине было сукна, полотна, шелку и разных цветных материй.  Долго в предчувствии грозной беды отец ходил осунувшийся, побледневший. И даже, как узнал я потом, подавал тайком заявление, чтобы его перевели заведовать жестяно-скобяной лавкой.  Как оно там случилось, не знаю, но только вскоре зажили мы хорошо и весело.  Пришли к нам плотники, маляры; сняли со стены порыжелый отцовский портрет с кривыми трещинами поперек плеча и шашки, ободрали старые васильковые обои и все перестроили, перекрасили по-новому.  Рухлядь мы распродали старьевщикам или отдали дворнику, и стало у нас светло, просторно и даже как-то по-необычному пусто.  Но тревога - неясная, непонятная - прочно поселилась с той поры в нашей квартире. То она возникала вместе с неожиданным телефонным звонком, то стучалась в дверь по ночам под видом почтальона или случайно запоздавшего гостя, то пряталась в уголках глаз вернувшегося с работы отца.  И я эту тревогу видел и чувствовал, но мне говорили, что ничего нет, что просто отец устал. А вот придет весна, и мы все втроем поедем на Кавказ - на курорт.  Пришла наконец весна, и отца моего отдали под суд.  Это случилось как раз в тот день, когда возвращался я из школы очень веселый, потому что наконец-то поставили меня старшим барабанщиком нашего четвертого отряда.  И, вбегая к себе во двор, где шумели под теплым солнцем соседские ребятишки, громко отбивал я линейкой по ранцу торжественный марш-поход, когда всей оравой кинулись они мне навстречу, наперебой выкрикивая, что у нас дома был обыск и отца моего забрала милиция и увезла в тюрьму.   Не скрою, что я долго плакал. Валентина ласково утешала меня и терпеливо учила, что я должен буду отвечать, если меня спросит судья или следователь.  Однако никто и ни о чем меня не спрашивал. Все там быстро разобрали сами и отца приговорили к пяти годам, за растрату.  Я узнал об этом уже перед сном, лежа в постели. Я забрался с головой под одеяло. Через потертую ткань слабо, как звездочки, мерцали желтые искры света.  За дверью ванной плескалась вода. Набухшие от слез глаза смыкались, и мне казалось, что я уплываю куда-то очень далеко.  "Прощай! - думал я об отце. - Сейчас мне двенадцать, через пять - будет семнадцать, детство пройдет, и в мальчише ...

# %% [markdown]
# #### Теперь разбиваем этот отрывок по предложениям и выводим первые 10 предложений:

# %%
sent_tokenize_list = sent_tokenize(data[0][0])
for sent_index, sent in enumerate(sent_tokenize_list[:10]):
    print("#{}:{}".format(sent_index, sent))
# Out:
# #0: Аркадий Гайдар.
# #1:Судьба барабанщика     ---------------------------------------------------------------------  Книга: А.Гайдар.
# #2:Собрание сочинений в трех томах.
# #3:Том 2  Издательство "Правда", Москва, 1986  OCR & SpellCheck: Zmiy (zpdd@chat.ru), 13 декабря 2001  ---------------------------------------------------------------------    Когда-то мой отец воевал с белыми, был ранен, бежал из плена, потом по должности командира саперной роты ушел в запас.
# #4:Мать моя утонула, купаясь на реке Волге, когда мне было восемь лет.
# #5:От большого горя мы переехали в Москву.
# #6:И здесь через два года отец женился на красивой девушке Валентине Долгунцовой.
# #7:Люди говорят, что сначала жили мы скромно и тихо.
# #8:Небогатую квартиру нашу держала Валентина в чистоте.
# #9:Одевалась просто.

# %% [markdown]
# #### Определяем функцию, которая парсит по одному предложению и выводит доп. информацию:

# %%
def parse_one_sentence(one_sentence):
    doc = nlp(one_sentence)
    for token in doc:
        print('{} \ {} \ {} \ {} \ {} \ {}'.format(
            token.text, 
            token.lemma_,
            token.pos_, 
            token.tag_, 
            token.dep_, 
            token.head.text
        ))

for sent_index, sent in enumerate(sent_tokenize_list[:5]):
    print("Sentence #{}\t{}".format(sent_index,sent))
    parse_one_sentence(sent)
    print('\n\n')
# Out:
# Sentence #0	 Аркадий Гайдар.
#   \   \ SPACE \  \  \ Аркадий
# Аркадий \ аркадий \ VERB \ VERB__Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Mid \ ROOT \ Аркадий
# Гайдар \ гайдар \ PROPN \ PROPN__Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur \ nsubj \ Аркадий
# . \ . \ PUNCT \ PUNCT___ \ punct \ Аркадий
#
#
#
# Sentence #1	Судьба барабанщика     ---------------------------------------------------------------------  Книга: А.Гайдар.
# Судьба \ судьба \ NOUN \ NOUN__Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing \ nsubj \ ---------------------------------------------------------------------
# барабанщика \ барабанщика \ PROPN \ PROPN__Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing \ appos \ Судьба
#      \      \ SPACE \ _SP \  \ барабанщика
# --------------------------------------------------------------------- \ --------------------------------------------------------------------- \ PUNCT \ PUNCT___ \ ROOT \ ---------------------------------------------------------------------
#   \   \ SPACE \  \  \ ---------------------------------------------------------------------
# Книга \ книга \ PROPN \ PROPN__Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing \ nmod \ ---------------------------------------------------------------------
# : \ : \ PUNCT \ PUNCT___ \ punct \ Книга
# А.Гайдар \ а.гайдар \ PROPN \ PROPN__Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing \ parataxis \ Книга
# . \ . \ PUNCT \ PUNCT___ \ punct \ А.Гайдар
#
#
#
# Sentence #2	Собрание сочинений в трех томах.
# Собрание \ собрание \ NOUN \ NOUN__Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing \ ROOT \ Собрание
# сочинений \ сочинение \ NOUN \ NOUN__Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur \ nmod \ Собрание
# в \ в \ ADP \ ADP___ \ case \ томах
# трех \ три \ NUM \ NUM__Case=Loc \ nummod \ томах
# томах \ тома \ NOUN \ NOUN__Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur \ nmod \ Собрание
# . \ . \ PUNCT \ PUNCT___ \ punct \ Собрание
#
#
#
# Sentence #3	Том 2  Издательство "Правда", Москва, 1986  OCR & SpellCheck: Zmiy (zpdd@chat.ru), 13 декабря 2001  ---------------------------------------------------------------------    Когда-то мой отец воевал с белыми, был ранен, бежал из плена, потом по должности командира саперной роты ушел в запас.
# Том \ том \ NOUN \ NOUN__Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing \ ROOT \ Том
# 2 \ 2 \ NUM \ NUM___ \ nummod \ Том
#   \   \ SPACE \  \  \ 2
# Издательство \ издательство \ PROPN \ PROPN__Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing \ nsubj \ Том
# " \ " \ PUNCT \ PUNCT___ \ punct \ Правда
# Правда \ правда \ NOUN \ NOUN__Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing \ appos \ Издательство
# " \ " \ PUNCT \ PUNCT___ \ punct \ Правда
# , \ , \ PUNCT \ PUNCT___ \ punct \ Правда
# Москва \ москва \ PROPN \ PROPN__Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing \ appos \ Издательство
# , \ , \ PUNCT \ PUNCT___ \ punct \ 1986
# 1986 \ 1986 \ NUM \ NUM___ \ nummod \ OCR
#   \   \ SPACE \  \  \ 1986
# OCR \ ocr \ PROPN \ PROPN__Foreign=Yes \ flat:foreign \ Издательство
# & \ & \ PROPN \ PROPN__Foreign=Yes \ flat:foreign \ Издательство
# SpellCheck \ spellcheck \ PROPN \ PROPN__Foreign=Yes \ flat:foreign \ Издательство
# : \ : \ PUNCT \ PUNCT___ \ punct \ SpellCheck
# Zmiy \ zmiy \ PROPN \ PROPN__Foreign=Yes \ flat:foreign \ Издательство
# ( \ ( \ PUNCT \ PUNCT___ \ punct \ zpdd@chat.ru
# zpdd@chat.ru \ zpdd@chat.ru \ VERB \ VERB__Aspect=Imp|Mood=Imp|Number=Sing|Person=2|VerbForm=Fin|Voice=Act \ appos \ Издательство
# ) \ ) \ PUNCT \ PUNCT___ \ punct \ zpdd@chat.ru
# , \ , \ PUNCT \ PUNCT___ \ punct \ zpdd@chat.ru
# 13 \ 13 \ NUM \ NUM___ \ nummod \ Издательство
# декабря \ декабрь \ NOUN \ NOUN__Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing \ flat \ 13
# 2001 \ 2001 \ NUM \ NUM___ \ nummod \ ---------------------------------------------------------------------
#   \   \ SPACE \  \  \ 2001
# --------------------------------------------------------------------- \ --------------------------------------------------------------------- \ PUNCT \ PUNCT___ \ nmod \ 13
#     \     \ SPACE \ _SP \  \ ---------------------------------------------------------------------
# Когда \ когда \ SCONJ \ SCONJ___ \ amod \ Том
# - \ - \ PUNCT \ PUNCT___ \ punct \ то
# то \ то \ PART \ PART___ \ discourse \ Когда
# мой \ мой \ DET \ DET__Case=Nom|Gender=Masc|Number=Sing \ det \ отец
# отец \ отец \ NOUN \ NOUN__Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing \ nsubj \ воевал
# воевал \ воевать \ VERB \ VERB__Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act \ parataxis \ Том
# с \ с \ ADP \ ADP___ \ case \ белыми
# белыми \ белый \ ADJ \ ADJ__Case=Ins|Degree=Pos|Number=Plur \ obl \ воевал
# , \ , \ PUNCT \ PUNCT___ \ punct \ ранен
# был \ был \ AUX \ AUX__Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act \ aux:pass \ ранен
# ранен \ ранить \ VERB \ VERB__Aspect=Imp|Gender=Masc|Number=Sing|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass \ conj \ воевал
# , \ , \ PUNCT \ PUNCT___ \ punct \ бежал
# бежал \ бежать \ VERB \ VERB__Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act \ conj \ воевал
# из \ из \ ADP \ ADP___ \ case \ плена
# плена \ плен \ NOUN \ NOUN__Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing \ obl \ бежал
# , \ , \ PUNCT \ PUNCT___ \ punct \ ушел
# потом \ потом \ ADV \ ADV__Degree=Pos \ advmod \ ушел
# по \ по \ ADP \ ADP___ \ case \ должности
# должности \ должность \ NOUN \ NOUN__Animacy=Inan|Case=Dat|Gender=Fem|Number=Sing \ obl \ ушел
# командира \ командир \ NOUN \ NOUN__Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing \ nmod \ должности
# саперной \ сапёрный \ ADJ \ ADJ__Case=Gen|Degree=Pos|Gender=Fem|Number=Sing \ amod \ роты
# роты \ рота \ NOUN \ NOUN__Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing \ nmod \ командира
# ушел \ уйти \ VERB \ VERB__Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act \ conj \ воевал
# в \ в \ ADP \ ADP___ \ case \ запас
# запас \ запас \ NOUN \ NOUN__Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing \ obl \ ушел
# . \ . \ PUNCT \ PUNCT___ \ punct \ ушел
#
#
#
# Sentence #4	Мать моя утонула, купаясь на реке Волге, когда мне было восемь лет.
# Мать \ мать \ NOUN \ NOUN__Animacy=Anim|Case=Nom|Gender=Fem|Number=Sing \ nsubj \ утонула
# моя \ мой \ DET \ DET__Case=Nom|Gender=Fem|Number=Sing \ det \ Мать
# утонула \ утонуть \ VERB \ VERB__Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act \ ROOT \ утонула
# , \ , \ PUNCT \ PUNCT___ \ punct \ купаясь
# купаясь \ купаться \ VERB \ VERB__Aspect=Imp|Tense=Pres|VerbForm=Conv|Voice=Mid \ advcl \ утонула
# на \ на \ ADP \ ADP___ \ case \ реке
# реке \ реке \ NOUN \ NOUN__Animacy=Anim|Case=Loc|Gender=Masc|Number=Sing \ obl \ купаясь
# Волге \ волге \ PROPN \ PROPN__Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing \ nmod \ реке
# , \ , \ PUNCT \ PUNCT___ \ punct \ купаясь
# когда \ когда \ SCONJ \ SCONJ___ \ mark \ было
# мне \ я \ PRON \ PRON__Case=Dat|Number=Sing|Person=1 \ nmod \ было
# было \ было \ AUX \ AUX__Aspect=Imp|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act \ advcl \ утонула
# восемь \ восемь \ NUM \ NUM__Animacy=Inan|Case=Acc \ nummod:gov \ лет
# лет \ год \ NOUN \ NOUN__Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur \ nsubj \ было
# . \ . \ PUNCT \ PUNCT___ \ punct \ было

# %% [markdown]
# ### Выведем семантические деревья для некоторых предложений текста:

# %% [markdown]
# #### Через потертую ткань слабо, как звездочки, мерцали желтые искры света.

# %%
from nltk import Tree

# используем одно из предложений
doc = nlp(sent_tokenize_list[43])
print(doc)

# построим для него семантическое дерево
def to_nltk_tree(node):
    if node.n_lefts + node.n_rights > 0:
        return Tree(node.orth_, [to_nltk_tree(child) for child in node.children])
    else:
        return node.orth_

to_nltk_tree(list(doc.sents)[0].root).pretty_print()
# Out:
# Через потертую ткань слабо, как звездочки, мерцали желтые искры света.
#                                    слабо
#          ____________________________|__________
#         |                    |               мерцали
#         |                    |             _____|_____________
#       ткань              звездочки        |     |           искры
#    _____|______        ______|_______     |     |       ______|_____
# Через       потертую  ,             как   ,     .    желтые       света

# %% [markdown]
# #### Да ты помнишь, как Чарли Чаплин летит в воду?

# %%
from nltk import Tree

# используем одно из предложений
doc = nlp(sent_tokenize_list[120])
print(doc)

# построим для него семантическое дерево
def to_nltk_tree(node):
    if node.n_lefts + node.n_rights > 0:
        return Tree(node.orth_, [to_nltk_tree(child) for child in node.children])
    else:
        return node.orth_

to_nltk_tree(list(doc.sents)[0].root).pretty_print()
# Out:
# Да ты помнишь, как Чарли Чаплин летит в воду?
#             помнишь
#   _____________|______
#  |   |              летит
#  |   |    ____________|___________
#  |   |   |     |      |   Чарли  воду
#  |   |   |     |      |     |     |
#  Да  ты  ,    как     ?   Чаплин  в

# %% [markdown]
# #### Полтораста рублей оставила, - ответил я и, тотчас же спохватившись, объяснил: - Это на целый месяц оставила.

# %%
# используем одно из предложений
doc = nlp(sent_tokenize_list[130])
print(doc)

# построим для него семантическое дерево
def to_nltk_tree(node):
    if node.n_lefts + node.n_rights > 0:
        return Tree(node.orth_, [to_nltk_tree(child) for child in node.children])
    else:
        return node.orth_

to_nltk_tree(list(doc.sents)[0].root).pretty_print()
# Out:
# Полтораста рублей оставила, - ответил я и, тотчас же спохватившись, объяснил: - Это на целый месяц оставила.
#                                              оставила
#      ___________________________________________|________________
#     |             |         |        |                        объяснил
#     |             |         |        |           ________________|________
#     |             |         |  спохватившись    |      |               оставила
#     |             |         |        |          |      |    ______________|___________
# Полтораста     ответил      и      тотчас       |      |   |     |        |         месяц
#     |        _____|_____    |        |          |      |   |     |        |       ____|_____
#   рублей    ,     -     я   ,        же         ,      :   -    Это       .      на       целый

# %% [markdown]
# ### Определим функцию для получения атрибутов, которая характеризует авторский стиль.

# %% [markdown]
# #### Нас интересует число слов в предложении, число потомков корня, глубина семантического дерева.

# %%
def attr(doc):
    out = {'sentSize': len(doc)} # число слов в предложении
    for word in doc:
        if word.dep_ =='ROOT': out.update({'rootChild': len(list(word.children))}) # число потомков корня

    import json
    def depth(jsn): # глубина семантического дерева
        if 'modifiers' in jsn.keys():
            return 1 +  max([0] + list(map(depth, jsn['modifiers'])))
        else:
            return 1

    j = json.loads(str(doc.print_tree()[0]).replace('\'', "\""))
    out.update({'depthTree': depth(j)}) 
    return out

# %% [markdown]
# #### Выводим значения этих атрибутов:

# %%
attr(doc)
# Out:
# {'sentSize': 22, 'rootChild': 5, 'depthTree': 5}

# %% [markdown]
# ### Вычисляем число различных трилетов, встречающихся в тексте:

# %%
from itertools import combinations

def treelets(data, topN=10):
    import operator
    from collections import OrderedDict
    from operator import itemgetter
    
    def trSort(tr):
        return dict((sorted(tr.items(), key=itemgetter(1)))[-topN:])
    
    one_gram_treelet = {}
    two_gram_treelet = {}
    three_gram_treelet = {}
    for sent in sent_tokenize(data):
        doc = nlp(sent)

        for token in doc:
            key = token.pos_
            one_gram_treelet.update({key: one_gram_treelet.get(key, 0) + 1})

            key = (token.head.pos_, token.dep_, token.pos_)
            two_gram_treelet.update({key: two_gram_treelet.get(key, 0) + 1})

            for (left_child, right_child) in combinations(token.children, 2):
                if left_child.dep_ != 'punct' and right_child.dep_ != 'punct':
                    key = (1, left_child.pos_, left_child.dep_, token.pos_, right_child.dep_, right_child.pos_)
                    three_gram_treelet.update({key: three_gram_treelet.get(key, 0) + 1})
            if token.dep_ != 'ROOT':
                for child in token.children:
                    if child.dep_ == 'punct' or token.dep_ == 'punct':
                        continue
                    key = (2, child.pos_, child.dep_, token.pos_, token.dep_, token.head.pos_)
                    three_gram_treelet.update({key: three_gram_treelet.get(key, 0) + 1})
                    
    return (len(sent_tokenize(data)), trSort(one_gram_treelet), trSort(two_gram_treelet), trSort(three_gram_treelet))

# %%
(numOfSents, sorted_1gram_treelet, sorted_2gram_treelet, sorted_3gram_treelet) = treelets(data[0][0])
print(numOfSents)
print(sorted_1gram_treelet)
# Out:
# 1712
# {'SCONJ': 424, 'PART': 966, 'CCONJ': 1046, 'ADV': 1297, 'ADJ': 1379, 'ADP': 1542, 'PRON': 1919, 'VERB': 2928, 'NOUN': 3485, 'PUNCT': 5066}

# %%
print(sorted_2gram_treelet)
print(list(sorted_2gram_treelet.keys()))
# Out:
# {('VERB', 'cc', 'CCONJ'): 629, ('VERB', 'conj', 'VERB'): 665, ('VERB', 'advmod', 'ADV'): 725, ('NOUN', 'amod', 'ADJ'): 725, ('VERB', 'nsubj', 'PRON'): 885, ('VERB', 'obl', 'NOUN'): 1014, ('NOUN', 'punct', 'PUNCT'): 1020, ('NOUN', 'case', 'ADP'): 1140, ('VERB', 'ROOT', 'VERB'): 1176, ('VERB', 'punct', 'PUNCT'): 2565}
# [('VERB', 'cc', 'CCONJ'), ('VERB', 'conj', 'VERB'), ('VERB', 'advmod', 'ADV'), ('NOUN', 'amod', 'ADJ'), ('VERB', 'nsubj', 'PRON'), ('VERB', 'obl', 'NOUN'), ('NOUN', 'punct', 'PUNCT'), ('NOUN', 'case', 'ADP'), ('VERB', 'ROOT', 'VERB'), ('VERB', 'punct', 'PUNCT')]

# %%
print(sorted_3gram_treelet)
# Out:
# {(1, 'CCONJ', 'cc', 'VERB', 'advmod', 'ADV'): 203, (1, 'ADP', 'case', 'NOUN', 'amod', 'ADJ'): 230, (1, 'CCONJ', 'cc', 'VERB', 'obl', 'NOUN'): 239, (2, 'NOUN', 'obl', 'VERB', 'conj', 'VERB'): 243, (1, 'NOUN', 'obl', 'VERB', 'conj', 'VERB'): 245, (1, 'PRON', 'nsubj', 'VERB', 'obl', 'NOUN'): 258, (1, 'VERB', 'conj', 'VERB', 'conj', 'VERB'): 259, (1, 'PRON', 'nsubj', 'VERB', 'conj', 'VERB'): 298, (2, 'CCONJ', 'cc', 'VERB', 'conj', 'VERB'): 387, (2, 'ADP', 'case', 'NOUN', 'obl', 'VERB'): 791}

# %% [markdown]
# ## Кластеризация методом k-means

# %%
import numpy as np
import matplotlib.pyplot as plt

def sintAnalyze(X):
    sse = {}
    for k in range(1, 20):
        kmeans = KMeans(n_clusters=k).fit(X)
        sse[k] = kmeans.inertia_ 
    plt.figure()
    plt.plot(list(sse.keys()), list(sse.values()))
    plt.xlabel("Number of clusters")
    plt.ylabel("SSE")
    plt.show()
    
    kmeans = KMeans(n_clusters=5, random_state=0).fit(X)    
    matches = []
    for Nclust in range(5):
        clustMatches = []
        for Nauth in range(5):
            authMatches = 0
            for i in kmeans.predict(np.array(trAuth[Nauth])):
                if i == Nclust: authMatches += 1
            clustMatches.append(authMatches/len(trAuth[Nauth]))
        matches.append(clustMatches)

    for line in matches:
        for item in line:
            print("{:f}".format(item), end=' ')
        print(np.argmax(line), end='')
        print()

# %%
import pickle
import os.path
if not os.path.exists('dataTr.pickle'):
    trByAuth = []
    for authorTexts in data:
        trByText = []
        for text in authorTexts:
            trByText.append(treelets(text))
        trByAuth.append(trByText)
    with open('dataTr.pickle', 'wb') as f:
        pickle.dump(trByAuth, f)
else:
    with open('dataTr.pickle', 'rb') as f:
        trByAuth = pickle.load(f)

# %%
trAuth = []
for auth in trByAuth:
    trText = []
    for text in auth:
        numOfSent = text[0]
        numOfTreelets = list(map(lambda x: x/numOfSent, list(text[1].values()) + list(text[2].values()) + list(text[3].values())))
        trText.append(numOfTreelets)
    trAuth.append(trText)
    
# K-Means кластеризация
from sklearn.cluster import KMeans
Xtr = trAuth[0] + trAuth[1] + trAuth[2] + trAuth[3] + trAuth[4]

sintAnalyze(Xtr)
# Out:
# 0.875000 0.080000 0.100000 0.250000 0.062500 0
# 0.000000 0.440000 0.200000 0.083333 0.062500 1
# 0.000000 0.000000 0.600000 0.000000 0.812500 4
# 0.000000 0.000000 0.000000 0.333333 0.062500 3
# 0.125000 0.480000 0.100000 0.333333 0.000000 1

# %% [markdown]
# #### В матрице выше показана доля соответствия номера автора номеру кластера.

# %%
if not os.path.exists('data.pickle'):
    attrsByAuth = []
    for authorTexts in data:
        attrsByText = []
        for text in authorTexts:
            sents = sent_tokenize(text)
            attrBySent = []
            for sent in sents:
                doc = nlp(sent)
                try:
                    attrBySent.append(attr(doc))
                except:
                    pass
            attrsByText.append(attrBySent)
        attrsByAuth.append(attrsByText)
        with open('data.pickle', 'wb') as f:
            pickle.dump(attrsByAuth, f)
else:
    with open('data.pickle', 'rb') as f:
        attrsByAuth = pickle.load(f)

# %%
import numpy as np
for i in range(5):
    depthTreeMean = np.mean([sent['depthTree'] for sent in attrsByAuth[i][0]])
    depthTreeStd = np.std([sent['depthTree'] for sent in attrsByAuth[i][0]])
    print(depthTreeMean, depthTreeStd)
# Out:
# 3.878787878787879 1.5778308039563946
# 4.367857142857143 1.7789550647638572
# 4.471042471042471 2.0837047665590167
# 4.516393442622951 1.7155680919129348
# 4.578039927404719 2.296685168734718

# %%
aAuth = []
for auth in attrsByAuth:
    aText = []
    for text in auth:
        x = [0,0,0]
        n = len(text)
        for sent in text:
            x[0] += sent['depthTree'] / n
            x[1] += sent['rootChild'] / n
            x[2] += sent['sentSize'] / n
        aText.append(x)
    aAuth.append(aText)

# %%
X = np.array(aAuth[0] + aAuth[1] + aAuth[2] + aAuth[3] + aAuth[4])

# %%
sse = {}
for k in range(1, 20):
    kmeans = KMeans(n_clusters=k).fit(X)
    sse[k] = kmeans.inertia_

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(X)

# %%
matches = []
for Nclust in range(5):
    clustMatches = []
    for Nauth in range(5):
        authMatches = 0
        for i in kmeans.predict(np.array(aAuth[Nauth])):
            if i == Nclust: authMatches += 1
        clustMatches.append(authMatches/len(aAuth[Nauth]))
    matches.append(clustMatches)

# %%
for line in matches:
    for item in line:
        print("{:f}".format(item), end=' ')
    print(np.argmax(line), end='')
    print()
# Out:
# 0.375000 0.320000 0.100000 0.250000 0.062500 0
# 0.000000 0.440000 0.400000 0.000000 0.375000 1
# 0.000000 0.000000 0.000000 0.333333 0.125000 3
# 0.000000 0.200000 0.500000 0.333333 0.437500 2
# 0.625000 0.040000 0.000000 0.083333 0.000000 0

# %% [markdown]
# ## Построение дендрограмм

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
np.set_printoptions(precision=5, suppress=True)

# %%
Z = linkage(Xtr, 'ward')

# %%
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

c, coph_dists = cophenet(Z, pdist(Xtr))
c
# Out:
# 0.6108163235539268

# %%
def dendogramm(name):
    plt.figure(figsize=(25, 10))
    plt.title('Hierarchical Clustering Dendrogram по ' + name)
    plt.ylabel('distance')
    dendrogram(
        Z,
        labels=label_list,
        leaf_rotation=90., 
        leaf_font_size=12., 
    )
plt.show()

# %%
dendogramm("трилетам")

# %%
Z = linkage(X, 'ward')
c, coph_dists = cophenet(Z, pdist(X))
c
# Out:
# 0.6306395114680649

# %%
dendogramm("атрибутам дерева")

# %% [markdown]
# ### Выводы по дендрограммам:
